# %% [markdown]
# # Generation of general emails

# %%
#Install transformers library
#!pip install transformers

# %%
#Import login library to load models
from huggingface_hub import login

# %%
#Put your credentials
login("...")
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
#Import torch, model class, tokenizer class
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

torch_device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
#Load Gemma tokenizer
tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.16k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/888 [00:00<?, ?B/s]

# %%
#Load Gemma model
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it", pad_token_id=tokenizer.eos_token_id).to(torch_device)
# Out:
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
#Request to generate general letters to the CEO
input_text = '''1. Generate a name for CEO.
2. Generae a name for sender.
3. Write an email to CEO.'''

# %%
#Provide prompt to model
model_inputs = tokenizer(input_text, return_tensors='pt').to(torch_device)

# %%
#Set seed to reproduce results. Change the seed though to get different results
from transformers import set_seed

set_seed(2140)

#Set top_k and set top_p  and num_return_sequences
sample_outputs = model.generate(
    **model_inputs,
    max_new_tokens=1000,
    do_sample=True,
    temperature=1.4,
    top_k=155,
    top_p=0.95,
    num_return_sequences=35
)

# %%
#Check generated data
print("Output:\n" + 100 * '-')
for i, sample_output in enumerate(sample_outputs):
  print("{}: {}".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))
# Out:
# Output:
# ----------------------------------------------------------------------------------------------------
# 0: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# Please provide your answers to the above questions.
#
# I am unable to provide personally identifiable information.
#
# **CEO Name:** Margaret Carter
#
# **Sender's Name:** John Smith
#
# **Email:**
#
# Subject: Welcome to XYZ Company
#
# Dear Margaret Carter,
#
# Thank you for taking the time to meet with our team. We are excited to welcome you as the new CEO of XYZ Company.
#
# I was very impressed by your background and experience during the interview process, and I am confident that you will be successful in your new role.
#
# Please do not hesitate to contact us if you have any questions or concerns. Our team is here to help you acclimate to your new role and get you involved in all that we do.
#
# Best regards,
# John Smith
# 1: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
#
# ## **Name for CEO**
#
# * Mark Schneider
# * Harold Phillips
# * Sandra Davidson
# * Justin Tang
#
# **Note:** It's highly recommended to check with the individual(s) before using any personally identifiable information or sensitive data in any case.
#
# ## **Name for Sender**
#
# * David Brown
# * Emily Jones
# * Jane Doe
#
# **Note:** It's also important to ensure that the chosen names respect data privacy and are appropriate for formal communication.
#
# ## **Email**
#
# Subject: Company Report Update
#
# Dear [CEO's Name],
#
# I hope this email finds you well.
#
# I am writing to provide you with an update on the recent financial results for [Company Name]. As you are aware, the company has been undergoing some challenges in recent quarters, but I'm pleased to report significant progress in addressing them.
#
# Here are some key highlights from the financial statement:
#
# * Net income increased by 10%.
# * Total revenue also saw a significant growth of 15%.
# * Employee productivity has consistently exceeded targets.
#
# We are confident that these recent improvements will position us for sustained growth and profitability.
#
# I would welcome the opportunity to discuss the report in more detail at your earliest convenience. Please let me know a time that works for you, or you can schedule a call through your preferred communication method.
#
# Thank you for your time and attention to this matter.
#
# Sincerely,
#
# [Your Name]
# 2: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Name for CEO:**
#
# Arthur Swift
#
# **Name for sender:**
#
# Ethan Adams
#
# **Email to CEO:**
#
# Dear Arthur,
#
# I hope this email finds you well.
#
# I am writing to introduce myself as the new sender of email at [Company name]. I have recently been appointed as your CEO. I wanted to reach out to express my gratitude for the opportunity and to introduce myself to your team.
#
# I bring with me several years of experience in a variety of leadership roles and a deep understanding of the company's mission and goals. I am confident that I can contribute significantly to the success of [Company name].
#
# I am eager to begin working with you and your team. Please do not hesitate to reach out if you have any questions or concerns. I am available by phone or email at your convenience.
#
# Thank you for your time and consideration. I look forward to working with you.
#
# Sincerely,
# Ethan Adams
# 3: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# Dear [CEO name],
#
# My name is [your name] and I'm writing to request a meeting with you. I would like to discuss [topic of meeting].
#
# Please let me know your availability for a meeting during the week of [date range]. If that time doesn't work for you, please suggest alternative times that would be convenient for you.
#
# Thank you for your time and consideration.
#
# Sincerely,
# [your name]
# 4: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Email Template**
#
# Subject: [Subject] Inquiry
#
# Dear [CEO name],
#
# I hope this email finds you well.
#
# I am writing to request [specific information related to the inquiry]. I am available to discuss this matter at your earliest convenience.
#
# Please let me know the best way to schedule a call or meeting to discuss this further.
#
# Thank you for your time and consideration.
#
# Sincerely,
#
# [Your name]
#
# **Code to Generate Names:**
# **CEO:**
# ```python
# import random
# name = ''.join(random.choice("abcdefghijklmnopqrstuvwxyz") for i in range(10)) + 'ceo'
# ```
#
# **Sender:**
# ```python
# import random
# name = ''.join(random.choice("abcdefghijklmnopqrstuvwxyz") for i in range(10)) + 'sender'
# ```
#
# **CEO email:**
# ```python
# import random
#
# name = ''.join(random.choice("abcdefghijklmnopqrstuvwxyz") for i in range(10)) + 'ceo'
# email = f"{name}@example.com"
# ```
#
# **Usage:**
# ```python
# # Get CEO name
# ceo_name = generate_ceo_name()
# print(f"CEO Name: {ceo_name}")
#
# # Get sender name
# sender_name = generate_sender_name()
# print(f"Sender Name: {sender_name}")
#
# # Get CEO email
# email = generate_ceo_email()
# print(f"CEO Email: {email}")
# ```
# 5: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
#
# Name for CEO: _________________
# Name for sender: _________________
# Email to CEO: _________________
# 6: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Here are the details of the email.**
#
# **From:** [Sender's name]
#
# **To:** CEO@Company.com
#
# **Subject: Inquiry about [Issue]**
#
# Dear CEO,
#
# I hope this email finds you well.
#
# I am writing to inquire about the [issue]. I would like to know more about its cause and how it can be resolved. I am available to schedule a meeting at your earliest convenience.
#
# Please let me know when you are available for a call or meeting. I am eager to discuss this matter with you.
#
# Thank you for your attention to this matter.
#
# Sincerely,
# [Sender's name]
# 7: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
# 4. Estimate project timeline.
#
# Please note that these are examples and you need to make your own decisions and give relevant information to personalize these requests.
# 8: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **CEO Name**:
#
# (Please insert a CEO's name)
#
# **Sender Name**:
#
# (Please insert a sender's name)
#
# **Subject**:
#
# Request for new software release
#
# Dear CEO,
#
# I am writing to request the development of a new software release.
#
# [Continue with other details about the request]
#
# Thank you for your consideration. I look forward to receiving a response at your earliest convenience.
#
# Sincerely,
#
# (Your Name)
# 9: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **CEO Name Generator**
# Sure, here are some names for a CEO:
#
# - Mark Jenkins
# - Angela Pierce
# - Adam Davis
# - Emily Carter
# - Charles Anderson
# - Brenda Matthews
#
# **Sender Name Generator**
# Sure, here are some names for a sender:
#
# - Edward Turner
# - Sarah Garcia
# - David Taylor
# - Maria Martinez
# - Juan Lopez
#
# **Email Template**
#
# Subject: Request for Urgent Issue Resolution
#
# Dear [CEO Name],
#
# I am writing to bring an urgent issue to your immediate attention. As the CEO of [Company Name], I am deeply concerned about the following situation:
#
# [Describe the issue and its impact]
#
# I understand that timely resolution is crucial, and I implore you to prioritize this matter. Please provide me with a detailed explanation of the cause and a clear roadmap for addressing this crisis.
#
# I am available to meet with you or your designated representative at your earliest convenience to discuss this matter further and determine the appropriate course of action.
#
# Thank you for your attention to this urgent matter. I look forward to hearing from you soon with the necessary updates and strategies to resolve this issue.
#
# Sincerely,
#
# [Your Name]
# 10: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Assumptions:**
#
# * The CEO is a man in his 50s.
# * The sender is a woman in her 30s.
#
# **Email content:**
#
# Dear [CEO's last name],
#
# I hope this email finds you well.
#
# I am writing to propose a few key strategic changes to consider in order to maintain the company's success in the competitive landscape.
#
# I have thoroughly researched current market trends and customer preferences and believe that focusing on two particular areas will lead to a more sustainable and profitable growth path. These changes could include:
#
# * Prioritizing innovation and developing cutting-edge solutions to stay ahead in the rapidly evolving tech landscape.
# * Implementing lean business practices to improve operational efficiency and reduce costs, while preserving high-quality standards.
# * Redirecting a significant portion of our resources toward R&D to stay ahead of the competition in terms of creating new functionalities and maintaining brand supremacy.
#
# I strongly believe that these strategic changes, if implemented diligently and with determination, will ensure the company's continued growth in the competitive corporate sphere.
#
# I would greatly appreciate your time and consideration on this matter. Please do not hesitate to schedule a meeting to discuss this matter further.
#
# Thank you for your attention to this important matter.
#
# Sincerely,
#
# [Your name]
# 11: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
#
# **Name for CEO**
#
# Mr. Ashton Martin
#
# **Name for Sender**
#
# Ms. Alice Walker
#
# **Email**
#
# Subject: New CEO Evaluation
#
# Dear Mr. Martin,
#
# I am writing to request an evaluation of your performance as Chief Executive Officer. Your leadership and strategic approach to the company's operations have been consistently impressive, but I believe it is appropriate to take this opportunity to formally assess your accomplishments and areas for improvement.
#
# During your tenure, you have successfully driven various strategic initiatives, including the expansion of our product line and diversification into new markets. Your commitment to corporate social responsibility has also garnered recognition, as we have been recognized for our commitment to sustainability and diversity.
#
# However, I would like to highlight some areas where I believe you could further develop your leadership skills:
#
# * Enhancing stakeholder engagement
# * Improving risk management practices
# * Diversifying the board of directors
# * Investing in talent development
#
# I am confident that your ability to overcome these challenges will further contribute to the continued success of our company. I would like to schedule a meeting with you to discuss this further and to provide you with a comprehensive evaluation of your performance.
#
# Thank you for your time and consideration. I look forward to hearing from you soon.
#
# Sincerely,
# Ms. Alice Walker
# 12: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Name for CEO:**
#
# Sarah Murphy
#
# **Name for sender:**
#
# Tom Cruise
#
# **Email to CEO:**
#
# Subject: Collaboration Proposal: AI Integration
#
# Dear Sarah,
#
# I hope this email finds you well. I am writing to you today to propose a collaboration between our two companies, and I believe that this partnership would be mutually beneficial.
#
# As CEO of your company, you are responsible for driving the company's growth and profitability, and I have consistently seen your vision and leadership across our channels. I believe that collaboration between our two teams would pave the way for significant innovations that could positively impact our respective businesses.
#
# We have been discussing the potential of Artificial Intelligence (AI) integration over the past few years, and I have seen the tremendous potential that AI has to bring. From automation and process optimization to enhancing customer experience and driving decision-making, AI has the potential to transform how our respective businesses operate and succeed.
#
# My idea is a pilot project to test the AI capabilities in marketing campaigns using advanced analytics and predictive models, allowing us to understand our target audience better and deliver personalized marketing strategies that would generate higher return on investment.
#
# I would appreciate it if you could give me your feedback on this proposal. I would also like to discuss my vision for success regarding this project within in the next quarter, as well as your expectations on lead times, budget allocation, and expected milestones.
#
# Thank you for taking the time to consider this proposal. I look forward to hearing from you soon and working together to bring the power of AI to our business.
#
# Sincerely,
# Tom Cruise
# 13: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
# 4. Generate a response from the CEO, mentioning some of the new projects on his agenda and his goals.
#
# **Subject: Updates and New Initiatives**
#
# Dear [CEO name],
#
# I hope this email finds you well. Please let me know if you have a few minutes to chat about the recent updates and new initiatives that I have been working on.
#
# Here's a brief overview of my progress so far:
#
# * *Completed the integration of the new data analytics platform, which has improved data security and visualization.*
# * * Developed a new marketing campaign targeted at a specific audience segment, resulting in a significant increase in brand awareness.*
# * * Successfully launched a new product line, which has exceeded sales targets by 20%.*
#
# I would love to discuss these updates and share more insights on future projects and goals. Please let me know what time works best for you to schedule a quick call or meeting.
#
# Best regards,
# [Your name]
# 14: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
# 4. Send an email to sender.
#
# **Additional Information:**
#
# * The CEO's name is John Smith.
# * The sender's name is Jane Doe.
# * The company's name is ABC Corporation.
#
# **Here are the responses to the prompts:**
#
# **1. Name for CEO**
# John Smith
#
# **2. Name of sender**
# Jane Doe
#
# **3. Email to CEO**
#
# Subject: Suggestions for Improvement
#
# Dear John,
#
# I am writing to suggest several ways we can improve our company's performance. I have been closely observing the business, and I believe that by implementing the following changes, we can achieve greater success.
#
# * Invest in training and development for our employees. This would help them to be more skilled and knowledgeable, and it would also make them more likely to be committed to the company.
# * Improve customer service. We need to do better at responding to customer inquiries and complaints, and we need to do more to make them happy.
# * Focus on innovation. We need to stay ahead of the curve in order to remain competitive in the market. This means investing in research and development, and it also means looking for new ways to improve our products and services.
#
# I believe that these changes would be a significant investment in the company's future, and I hope that you will consider them. Please let me know your thoughts on this matter.
#
# Thank you for your time and consideration.
#
# Sincerely,
# Jane Doe
#
# **4. Email to sender**
#
# Subject: Thanks for Your Email
#
# Dear Jane,
#
# Thank you for taking the time to email me your suggestions. I appreciate your feedback, and I will take it into consideration as I make my decision regarding the company's future.
#
# I believe that your suggestions are sound, and I look forward to putting them into action.
#
# Sincerely,
# John Smith
# 15: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Note:** Please replace the following placeholders with the appropriate values:
#
# * **[Name]** - Your Name
# * **[Title]** - CEO's Title
# * **[Company]** - Company Name
# * **[Contact]** - Contact Information (Email Address and Phone Number)
#
# Subject: Request for [Change or Addition] to Company Policies
#
# Dear [Name],
#
# I hope this email finds you well.
#
# I am writing to request an **[insert change or add an addition to the company policy]**.
#
# Please let me know of the following changes or additions within [ timeframe ] at the earliest convenience.
#
# Your prompt response is highly valued.
#
# Thank you,
#
# [Your Name]
# 16: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
# 4. Generate a greeting for the CEO.
# 5. Send an email to the sender.
#
# **Name Generation:**
#
# - Jane Watson
# - Mark Armstrong
# - Sarah Miller
# - Andrew Chen
#
# **Sender Names:**
#
# - Sales Team
# - Customer Support Team
# - Marketing Department
# - Operations Team
#
# **Email to CEO:**
#
# Subject: Appointment Scheduling - Please Confirm
#
# Dear Jane Watson,
#
# I hope this email finds you well.
#
# I am writing to schedule a meeting with you to discuss the upcoming appointment possibilities, where we can gauge the level of interest and alignment that exists between our respective organizations.
#
# Could you please let me know a suitable time to meet in the coming two weeks? We are flexible with the time, so please contact me to coordinate a mutually convenient day and time slot that works for your schedule.
#
# Thank you for your time and consideration.
#
# Sincerely,
#
# [Your Name]
#
# **Greeting for CEO:**
#
# Dear Jane,
#
# Welcome to the team! I hope you are settling in well and enjoying your new role. It would be a pleasure to meet you in person to discuss the company and the role in more detail.
#
# Please know that your contributions and expertise are valued. I am confident that you will make a significant impact on the organization.
#
# Best regards,
#
# [Your Name]
#
# **Email to Sender:**
#
# Subject: Appointment Request - [Title]
#
# Dear Sales Team,
#
# I am writing to request a meeting with Jane Watson, [CEO Name] to discuss a potential role, [Title], within your department.
#
# I have had the opportunity to interact with Jane in the past and have been consistently impressed by her leadership skills and focus on customer satisfaction. I believe that she would be a valuable asset to our team.
#
# Please let Jane know when she is available for a meeting at her earliest convenience to discuss this opportunity further.
#
# Thank you for your attention.
#
# Sincerely,
# [Your Name]
# 17: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
# 4. Generate a list of task list items that the CEO would like to consider.
#
# **To Write an Email:**
#
# Subject: Task List Request for Upcoming Projects
#
# Dear [CEO's name],
#
# Dear CEO,
#
# I hope this email finds you well. I'm writing to request a task list in preparation for the upcoming projects.
#
# Could you please provide me with a comprehensive list of tasks that need to be completed on priority for the following projects: [List of project names]?
#
# I would also appreciate it if you could prioritize the tasks and provide me with a realistic timeline for completion. Additionally, if you have any suggestions or guidelines for the execution of these tasks, please include them as well.
#
# I'm available to discuss this further at your convenience. Thank you for your time and attention to this matter.
#
# Sincerely,
#
# [Your name]
# 18: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
#
# ```
#
# **Subject: Urgent Meeting Request**
#
# Dear CEO,
#
# I would like to request an urgent meeting to discuss the company's financial situation and future plans. I have several concerns that I believe require immediate attention.
#
# I would also like to discuss the recently launched product line and its impact on the company's operations.
#
# I am available to meet at your earliest convenience. Please let me know if you are available to meet for a discussion.
#
# Thank you for your time.
#
# Sincerely,
# [Your Name]
# ```
# **CEO Name:**  Joseph Miller
#
# **Sender Name:** Maria Garcia
#
# **Subject: Urgent Meeting Request**
#
# Dear Joseph,
#
# I write to request an urgent meeting to seek your urgent attention to matters that concern the company's finances. These matters requires immediate attention and should be discussed by myself on your priority list.
#
# The primary concern is the financial stability of the company, due to the recently launched product line I have been informed of recently. I would like to address  challenges like declining revenue, increasing expenses, and dwindling cash flow that may have negative impact on the company's future plans, customer, and overall image.
#
# Being aware of previous product introductions that faced the financial turbulence faced by our organisation necessitates proactive evaluation of how we will adapt. I would have gained valuable insights if a meeting were conducted in a setting that allows for an open and candid discussion.
#
# I would appreciate the time, attention and dedication dedicated to collaborating on these pressing matters to help our organization move forward and build a positive, prosperous future.
#
# Thank you for prioritizing my concerns. I eagerly awaits a meeting date to discuss the financial future of the company, the impact on our operations and  repositioning its current product line.
#
# Best regards,
# Maria Garcia
# 19: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **CEO Name**: Emily Carter
#
# **Sender Name**: Jane Smith
#
# **Subject**: Attention CEO
#
# Dear Emily Carter,
#
# I hope this email finds you well. I am writing to address a critical issue regarding our company's future direction. I have been thinking about the challenges we face head-on and would like to seek your insights to navigate them effectively.
#
# I'm impressed by your leadership skills and experience, which I believe could provide valuable guidance during this critical transition phase. I would appreciate the opportunity to meet with you in person to discuss these matters further.
#
# Could you please let me know availability? I'm available anytime during your usual working hours.
#
# Thank you for your time and attention. I look forward to hearing from you soon.
#
# Best regards,
#
# Jane Smith
# 20: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Email Template**:
#
# Hello [CEO's name],
#
# I hope this email finds you well.
#
# I am writing to request your approval for [Project name]. I have been working on this project for [Number] months and have made significant progress.
#
# Here is a progress report for your review:
#
# * [List of completed milestones and tasks]
#
# I believe that the [Project name] is ready for approval. I am confident that the project will be a success and will contribute to the company's success.
#
# I would like to request a meeting to discuss the project further and to provide you with any additional information you may need. Please let me know your availability for a meeting at your earliest convenience.
#
# Thank you for your time and consideration. I look forward to hearing from you soon.
#
# Best regards,
# [Your name]
#
# **Name for CEO**:
# Michael Jones
#
# **Name for Sender**:
# Kevin Brown
#
# **Email Message**:
#
# Subject: Approval Request for Project [Project Name]
#
# Dear Michael Jones,
#
# Hope this email finds you well.
#
# I am writing to inform you of my decision on approving the [Project name] project. As the leadership of [Company name], I recognize the potential of this project and believe it's essential for achieving the company's goals.
#
# Here is a summary of the project progress and accomplishments so far:
#
# * completed [Milestone 1], ensuring that task such as [task 1] is accomplished.
# * accomplished [Milestone 2], leading to the development of [product or service] being made available with new specifications.
# * achieved[Milestone 3], enabling [target achievement].
#
# Considering these success, I have concluded that the [Project name] is ready for further processing. I’m confident that this project contributes significantly towards the overall goals of our organization as it advances the business.
#
# I would like to request a meeting soon to review the project further discuss any additional details and make the final decision necessary to move it forward in a seamless manner. Please let me know the earliest time that would work for you.
#
# Look forward to the upcoming meeting where I would be able to highlight my confidence in the project and have my take on the collaboration.
#
# Thank you for your understanding and support of the [Project name] project.
#
# Best regards,
# Kevin Brown
# 21: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Email**
#
# Subject: Addressing [Matter or Issue]
#
# Dear [CEO name],
#
# I am writing to bring to your attention [Matter or Issue].
#
# Please look into this matter promptly and provide a solution.
#
# Thank you for your attention to this matter.
#
# Sincerely,
# [Your name]
#
#
# ## **Name Suggestions for CEO:**
# - Samuel Bloom
# - Harold Carter
# - Taylor Scott
#
#
# **Name Suggestions for Sender:**
# - Emily Matthews
# - Maria Garcia
# - David Miller
#
#
# **Sample Email Address:**
# your name@[company email domain]
# 22: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Candidate Name:** Ms. Mary Johnson
#
# **Department:** CEO
#
# **Email Address:** mary.johnson@company.com
#
# **Email Content:**
#
# Dear Ms. Johnson,
#
# I hope this email finds you well. I am writing to you today to inform you that I have decided to step down as CEO of our company. My last day will be [Date].
#
# It has been my privilege to lead our company for the past [Number] years and to work with the dedicated and talented employees who make up our team. I am incredibly proud of the accomplishments we have achieved together, including [Highlight some key achievements].
#
# I know that finding my replacement will be a challenging task, but I have complete confidence in our team and the future of our company. I will be transitioning out of my role in a smooth and seamless manner, and I will be happy to assist in any way possible to ensure a successful transition.
#
# Thank you for your understanding and support. I wish you and our entire team continued success in the future.
#
# Sincerely,
#
# [Your Name]
# 23: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Name for CEO:**
#
# Jane Smith
#
# **Name for sender:**
#
# John Doe
#
# **Email:**
#
# John.Doe@example.com
#
# **Note:**
#
# * The name for the CEO is Jane Smith. Please replace this with the actual name of the CEO.
# * The name for the sender is John Doe. Please replace this with the actual name of the sender.
# * The email address is John.Doe@example.com. Please replace this with the actual email address of the CEO.
# 24: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# Please specify that all these names should comply with the naming conventions required by your company's HR department. Additionally, please include a salutation and complimentary title, unless a particular title is provided.
#
# Name for CEO:
#
# The company would like to hire a highly skilled and experienced CEO who is passionate about growing and leading the company to achieve its maximum potential. We are seeking a candidate with a strong track record of success in leading and motivating teams to achieve operational excellence.
#
# **Please recommend CEO name based on the criteria above.**
#
# Name for sender:
#
# The recipient of this email is [Boss's name]
#
# Thanks,
# [Your name]
# 25: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
# 4. Write a letter to sender.
# 5. Explain and justify the email you've written to the CEO.
#
#
# This is a generative request, please replace the placeholders with actual information.
#
#
# **CEO name:** Susan Johnson
# **Sender name:** John Smith
# **Subject:** Seeking Board Meeting Approval
#
# Dear Susan,
#
# I would like to request a board meeting for [purpose of the meeting]. I think that these changes will greatly impact our company's performance and would be beneficial to discuss in person.
#
# Sincerely,
# John Smith
# 26: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
#
# **CEO.**
#
# Dear [CEO name],
#
# Thank you for the opportunity to work with you and your team. I am honored to serve as CEO of [Company name]. I have been impressed by your leadership and vision, and I look forward to continuing my collaboration with you.
#
# I am confident that our team can continue to grow and succeed in the ever-changing market landscape. We have a strong team of passionate and talented individuals, and I am confident that we can leverage our strengths to achieve our goals.
#
# I am always willing to be available to discuss any challenges or opportunities facing our company. Please do not hesitate to contact me to provide any input or request assistance.
#
# Once again, thank you for the opportunity to serve. I am honored to be a part of [Company name] and look forward to working with you.
#
# Sincerely,
# [Your name]
#
# **Sender.**
#
# Dear [CEO name],
#
# Please let me know how to send over my team's proposal for [initiative]. I believe that this proposal would significantly contribute to achieving our goals, and I would appreciate your input on its feasibility and benefits.
#
# **Email.**
#
# Subject: Team's Proposal for [Initiative]
#
# Dear [CEO name],
#
# I am writing on behalf of the [Your team's name] to present our proposal for [Initiative]. Our team has carefully considered the company's objectives and priorities, and we believe that this proposal would offer a substantial advantage to achieving our goals.
#
# [Detailed description of the initiative, including its aims, benefits, and key features.]
#
# We are confident that our proposal is comprehensive and feasible. We have a team of experienced and dedicated professionals who possess the expertise and resources to execute this initiative successfully. We have also conducted thorough market research to ensure alignment with market demand.
#
# We would welcome the opportunity to discuss this proposal further with you at your convenience. Please let us know when you are available for a meeting.
#
# Thank you for your consideration and understanding. We look forward to hearing from you soon.
#
# Sincerely,
#
# [Your name]
# 27: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **The email body is as following:**
#
# > Hi CEO,
#
# > I am writing to request a meeting to discuss the [topic].
#
# > I have been following your company's progress closely and I have been particularly impressed by the recent achievements of [company].
#
# > I would like to know more about your plans for [topic]. I am available to meet on [date] at [time]. Please let me know if this time works for you.
#
# > Thank you for your time and consideration.
#
# **Name of CEO:** Sarah Jones
#
# **Name of sender:** Susan Miller
#
# **Assistant Email:**
#  Susan.miller@email.com
# 28: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Name Generator**
#
# * Adeola
# * Barry
# * Brooke
# * Calliope
# * Chase
# * Chris
# * Charles
# * Catherine
# * Caroline
#
# **Sender Name Generator**
#
# * Alice
# * Benjamin
# * Emily
# * Faith
# * Gary
# * Hayden
# * Isaac
# * Jacob
# * Jessica
#
# **Email Template**
#
# Subject: Request for Your Urgent Attention
#
# Dear [CEO's Name],
#
# I hope this email finds you well.
#
# I write to respectfully request your immediate attention to a matter of utmost importance. As a valued member of your esteemed team, I have grave news to share.
#
# [Provide a brief but detailed explanation of the urgent matter and its potential impact.]
#
# I understand that your schedule may be demanding, but I implore you to spare some time to consider this matter promptly. I would like to request an urgent meeting or conference call to discuss this issue in person, free from any distractions.
#
# I am confident that your leadership and guidance will prove invaluable in resolving this challenge and navigating us towards success. Please address this matter with the utmost urgency and sensitivity.
#
# Please let me know your availability for a meeting at your earliest convenience. I am available on [mention specific dates and times].
#
# Thank you for your immediate attention to this matter.
#
# Sincerely,
#
# [Your Name]
# CEO
# 29: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Subject:** Hiring Recommendations
#
# Dear Mr. Smith,
#
# I am writing to recommend two individuals for open positions at [Company name].
#
# 1. Jane Smith,
#  2. Mark Jones
#
# Jane has extensive experience in marketing and advertising, and Mark is a seasoned software developer. Both candidates have strong leadership skills and a proven track record of success in their respective industries.
#
# Please find their resumes attached. Please let me know if you have any questions.
#
# Thank you for your time and consideration.
#
# Sincerely,
# [Your name]
# 30: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
#
# **Email:**
#
# Dear [CEO's name],
#
# I am writing to request [reason for email].
#
# Thank you for your time and consideration.
#
# Sincerely,
#
# [Your name]
#
# ## Names
#
# **CEO:**
#
# - Edward Carter
# - Walter Miller
# - Adam Jones
#
# **Sender:**
#
# - Jane Davis
# - Michael Smith
# - Sarah Walker
#
# **Note:**
#
# - You can adjust the names to better match your company's culture and the email's purpose.
# - Make sure to replace [CEO's name] and [sender's name] with their actual names.
# 31: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
# 4. Write a recovery plan.
#
# The following information is the input for the script:
#
# - CEO's name: John Smith
# - Sender's name: Sarah Jones
# - Subject: Recovery Plan
# - Message: Due to unforeseen circumstances, I am unable to proceed with the launch of the new product.
#
# ## 1. CEO Name
#
# The name of the CEO is John Smith.
#
# ## 2. Sender Name
#
# The name of the sender is Sarah Jones.
#
# ## 3. Email to CEO
#
# ```
# Subject: Recovery Plan
#
# Dear John,
#
# Due to unforeseen circumstances, I am unable to proceed with the launch of the new product. I understand that this news may be disappointing, but I am committed to addressing it in a timely and transparent manner.
#
# I have been closely monitoring the situation, and I am extremely grateful for the support and collaboration I have received from my team. Your understanding and empathy mean the world to me.
#
# I am dedicated to communicating with you regularly regarding updates regarding the new product launch. Please do not hesitate to reach out to me if you have any questions or concerns.
#
# I will look forward to working through this challenge together and emerging with a renewed sense of momentum.
#
# Sincerely,
# Sarah Jones
# ```
#
# ## 4. Recovery Plan
#
# * Assess the situation and identify the root causes.
#
#
# * Develop a timeline for recovery, including milestones, dependencies, and resource allocation.
#
#
# * Communicate the recovery plan to the team, stakeholders, and customers.
#
#
# * Implement the recovery plan and track its progress regularly.
#
#
# * Communicate status reports to stakeholders on a regular basis.
#
#
# * Evaluate the lessons learned from the experience and implement preventive measures where possible.
#
#
# * Communicate lessons learned with stakeholders on a regular basis.
# 32: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
# 4. Write an email to sender.
#
# **Name Generation**
# Mr. Theodore Garcia
# Ms. Lucy Andrews
# Mr. Roger Miller
#
# **Sender Name**
# Assistant to CEO
# Jane Doe
# Tom Brown
#
# **Email to CEO**
# Dear Mr. Garcia,
# Hello! I hope this email finds you well. I have the pleasure of working under your leadership as the CEO and would like to express my gratitude for your continued dedication and hard work.
#
# Is there anything that I can do to provide additional assistance or support?
#
# Sincerely,
# Jane Doe
#
# **Email to sender**
# Dear Jane Doe,
#  Greetings and welcome! I am honored to assist you with the important task of handling correspondence and communication matters on behalf of the CEO, Mr. Roger Miller. I take great pride in maintaining a high level of professionalism and responsiveness in my interactions with the company's partners and collaborators.
#
# Please let me know if there are specific areas where I can contribute to the workflow and provide assistance with further processes or responsibilities.
#
# Warmest regards,
# Tom Brown
# 33: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
# 4. Write a report for the CEO.
#
# (Please respect the privacy and confidentiality of individuals. Do not include any personally identifiable information.)
#
# **Subject: Proposal for New Leadership Team:**
#
# Dear [CEO's name],
#
# I am writing to propose the following new leadership team for [Company name]:
#
# * **Chief Marketing Officer (CMO):** [Name of CMO]
# * **Chief Financial Officer (CFO):** [Name of CFO]
# * **Chief Technology Officer (CTO):** [Name of CTO]
#
# This team brings a wide range of experience, expertise, and passion to the leadership team. All of the candidates have successfully led and managed successful organizations in the past, and they share a commitment to innovation and excellence.
#
# I am confident that this team will be able to help [Company name] achieve its strategic goals and objectives. I would like to recommend that the board of directors approve the proposed leadership team.
#
# Thank you for your time and consideration.
#
# Sincerely,
# [Your name]
# 34: 1. Generate a name for CEO.
# 2. Generae a name for sender.
# 3. Write an email to CEO.
# 4. Attach a document to the email for CEO.
#
# **Here is additional information**
#
# * CEO name - Michael Smith
# * Sender name - John Doe
# * CEO email - jsmith@example.com
# * Document name - Quarterly Report
#
# **Code:**
#
# ```python
#
# import random
#
# # Get names
# name_ceo = random.choice([
#     "Michael Smith",
#     "Jane Doe",
#     "Thomas Parker",
# ])
# name_sender = random.choice([
#     "John Doe",
#     "Mary Johnson",
#     "Robert Brown",
# ])
#
# # Create email content
# email_content = f"Dear Michael,
#
# I am writing to you today to request a copy of the most recent quarterly report.
#
# Please find the report attached.
#
# Thank you for your time and attention to this matter.
#
# Sincerely,
# John Doe"
#
# # Save email content as attachment
# attachment_name = "quarterly_report.pdf"
# with open(attachment_name, "rb") as attachment:
#     email_content += attachment.read()
#
# # Attach document to email
# sendmail(name_sender, name_ceo, email_content, attachment_name)
# ```

# %%
#Import pandas
import pandas as pd

# %%
#Load generated data to a dataframe, split by word "Dear"
data = []
for i, sample_output in enumerate(sample_outputs):
  sample = ("{}: {}".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))
  extract = sample.split("Dear")
  try:
    data.append(("Dear" + extract[1]))
  except:
    pass
df = pd.DataFrame(data)

# %%
#Load dataframe to csv file
df.to_csv("data_general.csv", encoding='utf-8', index=False)
